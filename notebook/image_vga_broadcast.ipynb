# %%
import cv
import cv2

import numpy as np
import matplotlib.pyplot as plt

# %%
vc = cv2.VideoCapture(1)

# %%
vc.isOpened()
# Out:
# True

# %%
vc.get(cv.CV_CAP_PROP_FRAME_WIDTH)
# Out:
# 640.0

# %%
vc.set(cv.CV_CAP_PROP_FRAME_WIDTH, 1920)
# Out:
# False

# %%
vc.set(cv.CV_CAP_PROP_FRAME_HEIGHT, 1080)
# Out:
# False

# %%
vc.set(cv.CV_CAP_PROP_FOURCC, cv.CV_FOURCC('M', 'J', 'P', 'G'))
# Out:
# True

# %%
vc.set(cv.CV_CAP_PROP_FPS, 30)cv.CV_FOURCC('M', 'J', 'P', 'G')
# Out:
# False

# %%
retval, frame = vc.read()

# %%
plt.imshow(frame)

# %%
retval, buf = cv2.imencode('.jpg', frame, (cv.CV_IMWRITE_JPEG_QUALITY, 100))

# %%
buf.shape
# Out:
# (923291, 1)

# %%
frame.flatten().shape
# Out:
# (6220800,)

# %%
frame.shape
# Out:
# (1080, 1920, 3)

# %%
import lcm
import forseti2

# %%
lc = lcm.LCM("udpm://239.255.76.67:7667?ttl=1")

# %%
msg = forseti2.image_t()

# %%
msg.channels = 3
msg.utime = 0
msg.width = 640
msg.height = 480
msg.image = cv2.imencode('.jpg', frame)[1]
msg.size = msg.image.shape[0]

# %%
lc.publish("sprocket/video1", msg.encode())
